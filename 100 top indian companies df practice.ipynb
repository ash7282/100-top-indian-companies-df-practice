# %%
import pandas as pd

# %%
data = pd.read_csv('D:\\PYTHON CODING\\DATASETS FOR PRACTICE\\Top 100 Companies in India\\revenuefinal.csv')

# %%
data.head()
# Out:
#    SerialNumber                                     Names   Rank Marketcap  \
# 0             1                              Shree Cement  #1344  $12.13 B
# 1             2                 Shriram Transport Finance  #1513  $10.42 B
# 2             3  National Mineral Development Corporation  #1914   $7.65 B
# 3             4                                       ACC  #2394   $5.59 B
# 4             5                             Siemens India   #985  $18.02 B
#
#   Share.Price            Categories  Revenue Country
# 0     $336.31                   NaN  $2.28 B   India
# 1      $27.76  💳 Financial services  $2.29 B   India
# 2       $2.61             ⛏️ Mining  $2.30 B   India
# 3      $29.69                Cement  $2.30 B   India
# 4      $50.60                   NaN  $2.33 B   India

# %%
df=data.copy()

# %%
df.head()
# Out:
#    SerialNumber                                     Names   Rank Marketcap  \
# 0             1                              Shree Cement  #1344  $12.13 B
# 1             2                 Shriram Transport Finance  #1513  $10.42 B
# 2             3  National Mineral Development Corporation  #1914   $7.65 B
# 3             4                                       ACC  #2394   $5.59 B
# 4             5                             Siemens India   #985  $18.02 B
#
#   Share.Price            Categories  Revenue Country
# 0     $336.31                   NaN  $2.28 B   India
# 1      $27.76  💳 Financial services  $2.29 B   India
# 2       $2.61             ⛏️ Mining  $2.30 B   India
# 3      $29.69                Cement  $2.30 B   India
# 4      $50.60                   NaN  $2.33 B   India

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SerialNumber  100 non-null    int64
#  1   Names         100 non-null    object
#  2   Rank          100 non-null    object
#  3   Marketcap     100 non-null    object
#  4   Share.Price   100 non-null    object
#  5   Categories    92 non-null     object
#  6   Revenue       100 non-null    object
#  7   Country       100 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 6.4+ KB

# %%
df.describe()
# Out:
#        SerialNumber
# count    100.000000
# mean      50.500000
# std       29.011492
# min        1.000000
# 25%       25.750000
# 50%       50.500000
# 75%       75.250000
# max      100.000000

# %%
df.columns
# Out:
# Index(['SerialNumber', 'Names', 'Rank', 'Marketcap', 'Share.Price',
#        'Categories', 'Revenue', 'Country'],
#       dtype='object')

# %%
df['Names'].unique()
# Out:
# array(['Shree Cement', 'Shriram Transport Finance',
#        'National Mineral Development Corporation', 'ACC', 'Siemens India',
#        'Rain Industries', 'ICICI Lombard', 'Reliance Infrastructure',
#        'IDFC FIRST Bank', 'Chambal Fertilisers', 'Adani Ports & SEZ',
#        'Madras Rubber Factory', 'Apollo Tyres', 'Cipla',
#        'Indian Railway Finance', 'Torrent Power', "Dr. Reddy's",
#        'Aurobindo Pharma', 'National Fertilizers',
#        'Hindustan Aeronautics', 'Indus Towers', 'IndusInd Bank',
#        'Hindustan Zinc', 'Power Finance Corp', 'Oil India',
#        'Bank of India', 'Bajaj Finance', 'Aditya Birla Capital',
#        'Indian Bank', 'Patanjali Foods', 'Ambuja Cements', 'TVS Motor',
#        'Hero MotoCorp', 'LTIMindtree', 'Asian Paints',
#        'Max Financial Services', 'Bajaj Auto', 'Adani Power',
#        'New India Assurance', 'Vodafone Idea',
#        'Powergrid Corporation of India', 'Titan Company', 'Ashok Leyland',
# ...

# %%
df['Country'].unique()
# Out:
# array(['India'], dtype=object)

# %%
df['Country']=df['Country'].dropna

# %%
df=df['Country'].dropna(axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\miniconda3\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     552             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     553         except KeyError:
# --> 554             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16368\10653554.py in ?()
# ----> 1 df=df['Country'].dropna(axis=1)
#
# ~\miniconda3\Lib\site-packages\pandas\core\series.py in ?(self, axis, inplace, how, ignore_index)
#    5602         """
#    5603         inplace = validate_bool_kwarg(inplace, "inplace")
#    5604         ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
# ...

# %%
df.head()
# Out:
#    SerialNumber                                     Names   Rank Marketcap  \
# 0             1                              Shree Cement  #1344  $12.13 B
# 1             2                 Shriram Transport Finance  #1513  $10.42 B
# 2             3  National Mineral Development Corporation  #1914   $7.65 B
# 3             4                                       ACC  #2394   $5.59 B
# 4             5                             Siemens India   #985  $18.02 B
#
#   Share.Price            Categories  Revenue  \
# 0     $336.31                   NaN  $2.28 B
# 1      $27.76  💳 Financial services  $2.29 B
# 2       $2.61             ⛏️ Mining  $2.30 B
# 3      $29.69                Cement  $2.30 B
# 4      $50.60                   NaN  $2.33 B
#
#                                              Country
# 0  <bound method Series.dropna of 0     <bound me...
# 1  <bound method Series.dropna of 0     <bound me...
# 2  <bound method Series.dropna of 0     <bound me...
# ...

# %%
df=df.drop(['Country'],axis=1)

# %%
df.head()
# Out:
#    SerialNumber                                     Names   Rank Marketcap  \
# 0             1                              Shree Cement  #1344  $12.13 B
# 1             2                 Shriram Transport Finance  #1513  $10.42 B
# 2             3  National Mineral Development Corporation  #1914   $7.65 B
# 3             4                                       ACC  #2394   $5.59 B
# 4             5                             Siemens India   #985  $18.02 B
#
#   Share.Price            Categories  Revenue
# 0     $336.31                   NaN  $2.28 B
# 1      $27.76  💳 Financial services  $2.29 B
# 2       $2.61             ⛏️ Mining  $2.30 B
# 3      $29.69                Cement  $2.30 B
# 4      $50.60                   NaN  $2.33 B

# %%
df['Rank']=df['Rank'].replace('#','',inplace=True)

# %%
df['Rank']
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
#       ...
# 95    None
# 96    None
# 97    None
# 98    None
# 99    None
# Name: Rank, Length: 100, dtype: object

# %%
df.head()
# Out:
#    SerialNumber                                     Names  Rank Marketcap  \
# 0             1                              Shree Cement  None  $12.13 B
# 1             2                 Shriram Transport Finance  None  $10.42 B
# 2             3  National Mineral Development Corporation  None   $7.65 B
# 3             4                                       ACC  None   $5.59 B
# 4             5                             Siemens India  None  $18.02 B
#
#   Share.Price            Categories  Revenue
# 0     $336.31                   NaN  $2.28 B
# 1      $27.76  💳 Financial services  $2.29 B
# 2       $2.61             ⛏️ Mining  $2.30 B
# 3      $29.69                Cement  $2.30 B
# 4      $50.60                   NaN  $2.33 B

# %%
dta=data.copy()

# %%
dta.head()
# Out:
#    SerialNumber                                     Names   Rank Marketcap  \
# 0             1                              Shree Cement  #1344  $12.13 B
# 1             2                 Shriram Transport Finance  #1513  $10.42 B
# 2             3  National Mineral Development Corporation  #1914   $7.65 B
# 3             4                                       ACC  #2394   $5.59 B
# 4             5                             Siemens India   #985  $18.02 B
#
#   Share.Price            Categories  Revenue Country
# 0     $336.31                   NaN  $2.28 B   India
# 1      $27.76  💳 Financial services  $2.29 B   India
# 2       $2.61             ⛏️ Mining  $2.30 B   India
# 3      $29.69                Cement  $2.30 B   India
# 4      $50.60                   NaN  $2.33 B   India

# %%
dta=dta.drop(['Country'],axis=1)

# %%
dta.head()
# Out:
#    SerialNumber                                     Names   Rank Marketcap  \
# 0             1                              Shree Cement  #1344  $12.13 B
# 1             2                 Shriram Transport Finance  #1513  $10.42 B
# 2             3  National Mineral Development Corporation  #1914   $7.65 B
# 3             4                                       ACC  #2394   $5.59 B
# 4             5                             Siemens India   #985  $18.02 B
#
#   Share.Price            Categories  Revenue
# 0     $336.31                   NaN  $2.28 B
# 1      $27.76  💳 Financial services  $2.29 B
# 2       $2.61             ⛏️ Mining  $2.30 B
# 3      $29.69                Cement  $2.30 B
# 4      $50.60                   NaN  $2.33 B

# %%
dta['Rank'].unique()
# Out:
# array(['#1344', '#1513', '#1914', '#2394', '#985', '#5410', '#1721',
#        '#4963', '#2098', '#4144', '#609', '#2053', '#2938', '#1257',
#        '#670', '#2334', '#1383', '#1829', '#5361', '#787', '#1995',
#        '#1191', '#1080', '#1048', '#2486', '#2016', '#339', '#2504',
#        '#1954', '#2076', '#1247', '#1444', '#1490', '#924', '#542',
#        '#3062', '#716', '#733', '#2695', '#1756', '#669', '#453', '#2289',
#        '#464', '#1960', '#2470', '#623', '#2600', '#1210', '#1102',
#        '#1313', '#2430', '#1198', '#2647', '#1258', '#239', '#1547',
#        '#434', '#4527', '#534', '#241', '#1193', '#479', '#1720', '#1779',
#        '#4323', '#1640', '#1135', '#605', '#576', '#350', '#461', '#2305',
#        '#1050', '#285', '#1057', '#501', '#756', '#635', '#1271', '#1375',
#        '#182', '#179', '#177', '#90', '#769', '#509', '#299', '#1120',
#        '#906', '#74', '#258', '#4702', '#519', '#1986', '#1327', '#525',
#        '#778', '#237', '#48'], dtype=object)

# %%
dta['Rank']=dta['Rank'].str.replace('#','')

# %%
dta['Rank']
# Out:
# 0     1344
# 1     1513
# 2     1914
# 3     2394
# 4      985
#       ...
# 95    1327
# 96     525
# 97     778
# 98     237
# 99      48
# Name: Rank, Length: 100, dtype: object

# %%
dta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SerialNumber  100 non-null    int64
#  1   Names         100 non-null    object
#  2   Rank          100 non-null    object
#  3   Marketcap     100 non-null    object
#  4   Share.Price   100 non-null    object
#  5   Categories    92 non-null     object
#  6   Revenue       100 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 5.6+ KB

# %%
dta.shape
# Out:
# (100, 7)

# %%
dta['Marketcap']
# Out:
# 0      $12.13 B
# 1      $10.42 B
# 2       $7.65 B
# 3       $5.59 B
# 4      $18.02 B
#         ...
# 95     $12.34 B
# 96     $35.43 B
# 97     $23.81 B
# 98     $68.75 B
# 99    $220.32 B
# Name: Marketcap, Length: 100, dtype: object

# %%
dta['Marketcap']=dta['Marketcap'].str.replace('$','')
dta['Marketcap']=dta['Marketcap'].str.replace('B','Cr')

# %%
dta['Marketcap']
# Out:
# 0      12.13 Cr
# 1      10.42 Cr
# 2       7.65 Cr
# 3       5.59 Cr
# 4      18.02 Cr
#         ...
# 95     12.34 Cr
# 96     35.43 Cr
# 97     23.81 Cr
# 98     68.75 Cr
# 99    220.32 Cr
# Name: Marketcap, Length: 100, dtype: object

# %%
dta['Marketcap']=dta['Marketcap'].str.replace('.','')

# %%
dta['Marketcap']
# Out:
# 0      1213 Cr
# 1      1042 Cr
# 2       765 Cr
# 3       559 Cr
# 4      1802 Cr
#         ...
# 95     1234 Cr
# 96     3543 Cr
# 97     2381 Cr
# 98     6875 Cr
# 99    22032 Cr
# Name: Marketcap, Length: 100, dtype: object

# %%
dta.head()
# Out:
#    SerialNumber                                     Names  Rank Marketcap  \
# 0             1                              Shree Cement  1344   1213 Cr
# 1             2                 Shriram Transport Finance  1513   1042 Cr
# 2             3  National Mineral Development Corporation  1914    765 Cr
# 3             4                                       ACC  2394    559 Cr
# 4             5                             Siemens India   985   1802 Cr
#
#   Share.Price            Categories  Revenue
# 0     $336.31                   NaN  $2.28 B
# 1      $27.76  💳 Financial services  $2.29 B
# 2       $2.61             ⛏️ Mining  $2.30 B
# 3      $29.69                Cement  $2.30 B
# 4      $50.60                   NaN  $2.33 B

# %%
dta['Share.Price']=dta['Share.Price'].str.replace('$','')

# %%
dta['Share.Price']
# Out:
# 0     336.31
# 1      27.76
# 2       2.61
# 3      29.69
# 4      50.60
#        ...
# 95      5.71
# 96      2.82
# 97      1.73
# 98     10.87
# 99     32.56
# Name: Share.Price, Length: 100, dtype: object

# %%
dta['Categories'].isnull().sum()
# Out:
# 0

# %%
dta['Categories']=dta['Categories'].count

# %%
nan_count=dta['Categories'].isna().sum()
print(nan_count)
# Out:
# 0

# %%
dta['Revenue']=dta['Revenue'].str.replace('$','')
dta['Revenue']=dta['Revenue'].str.replace('B','Cr')
dta['Revenue']=dta['Revenue'].str.replace('.','')
dta.head()
# Out:
#    SerialNumber                                     Names  Rank Marketcap  \
# 0             1                              Shree Cement  1344   1213 Cr
# 1             2                 Shriram Transport Finance  1513   1042 Cr
# 2             3  National Mineral Development Corporation  1914    765 Cr
# 3             4                                       ACC  2394    559 Cr
# 4             5                             Siemens India   985   1802 Cr
#
#   Share.Price  Categories Revenue
# 0      336.31           0  228 Cr
# 1       27.76           0  229 Cr
# 2        2.61           0  230 Cr
# 3       29.69           0  230 Cr
# 4       50.60           0  233 Cr

# %%
dta
# Out:
#     SerialNumber                                      Names  Rank Marketcap  \
# 0              1                               Shree Cement  1344   1213 Cr
# 1              2                  Shriram Transport Finance  1513   1042 Cr
# 2              3   National Mineral Development Corporation  1914    765 Cr
# 3              4                                        ACC  2394    559 Cr
# 4              5                              Siemens India   985   1802 Cr
# ..           ...                                        ...   ...       ...
# 95            96                           Bharat Petroleum  1327   1234 Cr
# 96            97                          Oil & Natural Gas   525   3543 Cr
# 97            98                                 Indian Oil   778   2381 Cr
# 98            99  Life Insurance Corporation of India (LIC)   237   6875 Cr
# 99           100                        Reliance Industries    48  22032 Cr
#
#    Share.Price  Categories   Revenue
# ...

# %%
dt=data.copy()

# %%
dt['Revenue']=dt['Revenue'].str.replace('$','')
dt['Revenue']=dt['Revenue'].str.replace('B','Cr')
dt['Revenue']=dt['Revenue'].str.replace('.','')
dt['Marketcap']=dt['Marketcap'].str.replace('$','')
dt['Marketcap']=dt['Marketcap'].str.replace('B','Cr')

# %%
dt
# Out:
#     SerialNumber                                      Names   Rank  Marketcap  \
# 0              1                               Shree Cement  #1344   12.13 Cr
# 1              2                  Shriram Transport Finance  #1513   10.42 Cr
# 2              3   National Mineral Development Corporation  #1914    7.65 Cr
# 3              4                                        ACC  #2394    5.59 Cr
# 4              5                              Siemens India   #985   18.02 Cr
# ..           ...                                        ...    ...        ...
# 95            96                           Bharat Petroleum  #1327   12.34 Cr
# 96            97                          Oil & Natural Gas   #525   35.43 Cr
# 97            98                                 Indian Oil   #778   23.81 Cr
# 98            99  Life Insurance Corporation of India (LIC)   #237   68.75 Cr
# 99           100                        Reliance Industries    #48  220.32 Cr
#
# ...

# %%
dt['Rank']=dt['Rank'].str.replace('#','')

# %%
dt
# Out:
#     SerialNumber                                      Names  Rank  Marketcap  \
# 0              1                               Shree Cement  1344   12.13 Cr
# 1              2                  Shriram Transport Finance  1513   10.42 Cr
# 2              3   National Mineral Development Corporation  1914    7.65 Cr
# 3              4                                        ACC  2394    5.59 Cr
# 4              5                              Siemens India   985   18.02 Cr
# ..           ...                                        ...   ...        ...
# 95            96                           Bharat Petroleum  1327   12.34 Cr
# 96            97                          Oil & Natural Gas   525   35.43 Cr
# 97            98                                 Indian Oil   778   23.81 Cr
# 98            99  Life Insurance Corporation of India (LIC)   237   68.75 Cr
# 99           100                        Reliance Industries    48  220.32 Cr
#
# ...

# %%
dt['Share.Price']=dt['Share.Price'].str.replace('$','')

# %%
dt=dt.drop(['Country'],axis=1)

# %%
dt
# Out:
#     SerialNumber                                      Names  Rank  Marketcap  \
# 0              1                               Shree Cement  1344   12.13 Cr
# 1              2                  Shriram Transport Finance  1513   10.42 Cr
# 2              3   National Mineral Development Corporation  1914    7.65 Cr
# 3              4                                        ACC  2394    5.59 Cr
# 4              5                              Siemens India   985   18.02 Cr
# ..           ...                                        ...   ...        ...
# 95            96                           Bharat Petroleum  1327   12.34 Cr
# 96            97                          Oil & Natural Gas   525   35.43 Cr
# 97            98                                 Indian Oil   778   23.81 Cr
# 98            99  Life Insurance Corporation of India (LIC)   237   68.75 Cr
# 99           100                        Reliance Industries    48  220.32 Cr
#
# ...

# %%
dt['Categories'][0:30]
# Out:
# 0                           NaN
# 1          💳 Financial services
# 2                     ⛏️ Mining
# 3                        Cement
# 4                           NaN
# 5                   🧪 Chemicals
# 6                   🏦 Insurance
# 7                 🔋 Electricity
# 8                       🏦 Banks
# 9                   🧪 Chemicals
# 10                      ⚓ Ports
# 11                        Tires
# 12                        Tires
# 13            💊 Pharmaceuticals
# 14                   🚂 Railways
# 15                🔋 Electricity
# 16            💊 Pharmaceuticals
# 17            💊 Pharmaceuticals
# 18       🌱 Fertilizer companies
# 19    ✈️ Aircraft manufacturers
# 20          📡 Telecommunication
# 21                      🏦 Banks
# 22                          NaN
# 23         💳 Financial services
# 24                    🛢 Oil&Gas
# 25                      🏦 Banks
# 26         💳 Financial services
# 27                  🏦 Insurance
# 28                      🏦 Banks
# ...

# %%
dt=dt.rename(columns={'Marketcap':'Marketcap.Cr','Share.Price':'Share.Price.Rs','Revenue':'Revenue.Cr'})

# %%
dt
# Out:
#     SerialNumber                                      Names  Rank  \
# 0              1                               Shree Cement  1344
# 1              2                  Shriram Transport Finance  1513
# 2              3   National Mineral Development Corporation  1914
# 3              4                                        ACC  2394
# 4              5                              Siemens India   985
# ..           ...                                        ...   ...
# 95            96                           Bharat Petroleum  1327
# 96            97                          Oil & Natural Gas   525
# 97            98                                 Indian Oil   778
# 98            99  Life Insurance Corporation of India (LIC)   237
# 99           100                        Reliance Industries    48
#
#    Marketcap.Cr Share.Price.Rs            Categories Revenue.Cr
# 0      12.13 Cr         336.31                   NaN     228 Cr
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SerialNumber    100 non-null    int64
#  1   Names           100 non-null    object
#  2   Rank            100 non-null    object
#  3   Marketcap.Cr    100 non-null    object
#  4   Share.Price.Rs  100 non-null    object
#  5   Categories      92 non-null     object
#  6   Revenue.Cr      100 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 5.6+ KB

# %%
dt['Marketcap.Cr']=dt['Marketcap.Cr'].str.replace('Cr','')
dt['Revenue.Cr']=dt['Revenue.Cr'].str.replace('Cr','')
dt
# Out:
#     SerialNumber                                      Names  Rank  \
# 0              1                               Shree Cement  1344
# 1              2                  Shriram Transport Finance  1513
# 2              3   National Mineral Development Corporation  1914
# 3              4                                        ACC  2394
# 4              5                              Siemens India   985
# ..           ...                                        ...   ...
# 95            96                           Bharat Petroleum  1327
# 96            97                          Oil & Natural Gas   525
# 97            98                                 Indian Oil   778
# 98            99  Life Insurance Corporation of India (LIC)   237
# 99           100                        Reliance Industries    48
#
#    Marketcap.Cr Share.Price.Rs            Categories Revenue.Cr
# 0        12.13          336.31                   NaN       228
# ...

# %%
dt[['Categories','Revenue.Cr']][0:31]
# Out:
#                    Categories Revenue.Cr
# 0                         NaN       228
# 1        💳 Financial services       229
# 2                   ⛏️ Mining       230
# 3                      Cement       230
# 4                         NaN       233
# 5                 🧪 Chemicals       235
# 6                 🏦 Insurance       238
# 7               🔋 Electricity       250
# 8                     🏦 Banks       254
# 9                 🧪 Chemicals       277
# 10                    ⚓ Ports       281
# 11                      Tires       290
# 12                      Tires       299
# 13          💊 Pharmaceuticals       302
# 14                 🚂 Railways       313
# 15              🔋 Electricity       320
# 16          💊 Pharmaceuticals       323
# 17          💊 Pharmaceuticals       323
# 18     🌱 Fertilizer companies       328
# 19  ✈️ Aircraft manufacturers       336
# 20        📡 Telecommunication       340
# 21                    🏦 Banks       350
# ...

# %%
dt['Categories'].unique()
# Out:
# array([nan, '💳 Financial services', '⛏️ Mining', 'Cement', '🧪 Chemicals',
#        '🏦 Insurance', '🔋 Electricity', '🏦 Banks', '⚓ Ports', 'Tires',
#        '💊 Pharmaceuticals', '🚂 Railways', '🌱 Fertilizer companies',
#        '✈️ Aircraft manufacturers', '📡 Telecommunication', '🛢 Oil&Gas',
#        '🍴 Food', '🏍 Motorcycle Manufacturers', '💼 Professional services',
#        '🎨 Paint & Coating', '⌚ Luxury goods', '🏭 Manufacturing',
#        '🚚 Transportation', '🛍️ Retail', '✈️ Airlines', '🚬 Tobacco',
#        '🔩 Steel producers', '🚘 Automotive Suppliers', '🏙 Conglomerate',
#        '🚗 Automakers', '🏗 Construction'], dtype=object)

# %%
dt.describe
# Out:
# <bound method NDFrame.describe of     SerialNumber                                      Names  Rank  \
# 0              1                               Shree Cement  1344
# 1              2                  Shriram Transport Finance  1513
# 2              3   National Mineral Development Corporation  1914
# 3              4                                        ACC  2394
# 4              5                              Siemens India   985
# ..           ...                                        ...   ...
# 95            96                           Bharat Petroleum  1327
# 96            97                          Oil & Natural Gas   525
# 97            98                                 Indian Oil   778
# 98            99  Life Insurance Corporation of India (LIC)   237
# 99           100                        Reliance Industries    48
#
#    Marketcap.Cr Share.Price.Rs            Categories Revenue.Cr
# 0        12.13          336.31                   NaN       228
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dt['Revenue.Cr'].mean
# Out:
# <bound method Series.mean of 0       228
# 1       229
# 2       230
# 3       230
# 4       233
#        ...
# 95     5411
# 96     7808
# 97     9487
# 98     9794
# 99    10619
# Name: Revenue.Cr, Length: 100, dtype: object>

# %%
dt['Revenue.Cr'].mode
# Out:
# <bound method Series.mode of 0       228
# 1       229
# 2       230
# 3       230
# 4       233
#        ...
# 95     5411
# 96     7808
# 97     9487
# 98     9794
# 99    10619
# Name: Revenue.Cr, Length: 100, dtype: object>

# %%
dt['Revenue.Cr'].median
# Out:
# <bound method Series.median of 0       228
# 1       229
# 2       230
# 3       230
# 4       233
#        ...
# 95     5411
# 96     7808
# 97     9487
# 98     9794
# 99    10619
# Name: Revenue.Cr, Length: 100, dtype: object>

# %%
dt.duplicate
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16368\3017526666.py in ?()
# ----> 1 dt.duplicate
#
# ~\miniconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'duplicate'

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SerialNumber    100 non-null    int64
#  1   Names           100 non-null    object
#  2   Rank            100 non-null    object
#  3   Marketcap.Cr    100 non-null    object
#  4   Share.Price.Rs  100 non-null    object
#  5   Categories      92 non-null     object
#  6   Revenue.Cr      100 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 5.6+ KB

# %%
dt['Rank'].dtype
# Out:
# dtype('O')

# %%
dt['Rank']=dt['Rank'].astype('int')

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SerialNumber    100 non-null    int64
#  1   Names           100 non-null    object
#  2   Rank            100 non-null    int32
#  3   Marketcap.Cr    100 non-null    object
#  4   Share.Price.Rs  100 non-null    object
#  5   Categories      92 non-null     object
#  6   Revenue.Cr      100 non-null    object
# dtypes: int32(1), int64(1), object(5)
# memory usage: 5.2+ KB

# %%
dt['Share.Price.Rs'].unique()
# Out:
# array(['336.31', '27.76', '2.61', '29.69', '50.60', '2.11', '17.84',
#        '2.59', '0.96', '4.44', '13.79', '1,647', '6.23', '16.48', '2.09',
#        '12.04', '69.54', '13.85', '1.51', '34.94', '2.71', '18.19',
#        '3.77', '5.04', '4.85', '1.58', '85.26', '1.99', '5.54', '19.03',
#        '6.74', '23.36', '53.45', '66.12', '35.49', '10.57', '91.42',
#        '6.54', '2.78', '0.18', '2.95', '45.37', '2.04', '16.46', '4.24',
#        '6.48', '44.93', '6.47', '1.26', '15.91', '1.69', '4.22', '4.39',
#        '3.09', '34.45', '29.22', '5.60', '21.28', '9.63', '119.96',
#        '5.48', '2.73', '12.55', '8.62', '5.85', '2.08', '1.39', '6.97',
#        '5.72', '19.62', '18.65', '34.82', '1.43', '16.62', '32.87',
#        '24.99', '118.90', '19.68', '4.69', '3.17', '13.97', '20.22',
#        '24.13', '56.61', '9.82', '3.79', '43.24', '6.83', '1.61', '45.85',
#        '7.37', '4.23', '9.77', '5.18', '5.71', '2.82', '1.73', '10.87',
#        '32.56'], dtype=object)

# %%
dt['Share.Price.Rs']=dt['Share.Price.Rs'].str.replace(',','.')

# %%
dt['Marketcap.Cr']=dt['Marketcap.Cr'].astype('float')
dt['Share.Price.Rs']=dt['Share.Price.Rs'].astype('float')
dt['Revenue.Cr']=dt['Revenue.Cr'].astype('int')
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SerialNumber    100 non-null    int64
#  1   Names           100 non-null    object
#  2   Rank            100 non-null    int32
#  3   Marketcap.Cr    100 non-null    float64
#  4   Share.Price.Rs  100 non-null    float64
#  5   Categories      92 non-null     object
#  6   Revenue.Cr      100 non-null    int32
# dtypes: float64(2), int32(2), int64(1), object(2)
# memory usage: 4.8+ KB

# %%
sns.barplot(data=dt,x='Categories',y='Revenue.Cr',orient='y')
plt.title("Comparision of categories and Revenue")
plt.xlabel('Categories')
plt.ylabel('Revenue.Cr')
plt.show()
# Out:
# C:\Users\AshEdito\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128179 (\N{CREDIT CARD}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\AshEdito\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9935 (\N{PICK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\AshEdito\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 129514 (\N{TEST TUBE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\AshEdito\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 127974 (\N{BANK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\AshEdito\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128267 (\N{BATTERY}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
